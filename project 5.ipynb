# %% [markdown]
# * bullet
#
# **bold**
#
# $ \sqrt(2+3) $

# %%
# to use python in the cloud go to
# notebooks.azure.com - sign in, create user ID, 
# in azure notebooks are organised in libraries - create a new one doesn't need to be public
# azure runs on instance of linux - so can use linus commands like ls

# %%
import pandas as pd
import numpy as np
import seaborn as sns
planetData = [['MERCURY', 0.33, 4879, 4222.6, 57.9, 88, 47.4, 167, 0, 0, 'No', 'Yes', '1974-03-29', 'Mariner 10'],
          ['VENUS', 4.87, 12104, 2802, 108.2, 224.7, 35, 464, 92, 0, 'No', 'No', '1962-08-27', 'Mariner 2'],
          ['EARTH', 5.97, 12756, 24, 149.6, 365.2, 29.8, 15, 1, 1, 'No', 'Yes', 'NA', 'NA'],
          ['MOON', 0.073, 3475, 708.7, 'NA', 27.3, 1, -20, 0, 0, 'No', 'No', '1959-09-12', 'Luna 2'],
          ['MARS', 0.642, 6792, 24.7, 227.9, 687, 24.1, -65, 0.01, 2, 'No', 'N0', '1965-07-15', 'Mariner 4'],
          ['JUPITER', 1898, 142984, 9.9, 778.6, 4331, 13.1, -110, 'NA', 67, 'Yes', 'Yes', '1973-12-04', 'Pioneer 10'],
          ['SATURN', 568, 120536, 10.7, 1433.5, 10747, 9.7, -140, 'NA', 62, 'Yes', 'Yes', '1979-09-01', 'Pioneer 11'],
          ['URANUS', 86.8, 51118, 17.2, 2872.5, 30589, 6.8, -195, 'NA', 27, 'Yes', 'Yes', '1986-01-24', 'Voyager 2'],
          ['NEPTUNE', 102, 49528, 16.1, 4495.1, 59800, 5.4, -200, 'NA', 14, 'Yes', 'Yes', '1989-08-25', 'Voyager 2'],
          ['PLUTO', 0.0146, 2370, 153.3, 5906.4, 90560, 4.7, -225, 0.00001, 5, 'No', 'NA', '2015-07-14', 'New Horizons']]
colNames = ['Planet', 'Mass', 'Diameter', 'DayLength', 'SunDistance', 'OrbitPeriod', 'OrbitVelocity', 'Temperature', 'SurfacePressure', 'Moons', 'Rings', 'MagneticField', 'FirstVisited', 'FirstMission']

# %%
df = pd.DataFrame(data = planetData, columns=colNames)

# %%
df
# Out:
#     Planet       Mass  Diameter  DayLength SunDistance  OrbitPeriod  \
# 0  MERCURY     0.3300      4879     4222.6        57.9         88.0
# 1    VENUS     4.8700     12104     2802.0       108.2        224.7
# 2    EARTH     5.9700     12756       24.0       149.6        365.2
# 3     MOON     0.0730      3475      708.7          NA         27.3
# 4     MARS     0.6420      6792       24.7       227.9        687.0
# 5  JUPITER  1898.0000    142984        9.9       778.6       4331.0
# 6   SATURN   568.0000    120536       10.7      1433.5      10747.0
# 7   URANUS    86.8000     51118       17.2      2872.5      30589.0
# 8  NEPTUNE   102.0000     49528       16.1      4495.1      59800.0
# 9    PLUTO     0.0146      2370      153.3      5906.4      90560.0
#
#    OrbitVelocity  Temperature SurfacePressure  Moons Rings MagneticField  \
# 0           47.4          167               0      0    No           Yes
# ...

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.to_csv(path_or_buf='~/Documents/PyFilesJupy/df.csv', index = False)

# %%
#planets = pd.read_csv('~/Documents/PyFilesJupy/df.csv', usecols=(0, 1, 2, 3))
planets = pd.read_csv('~/Documents/PyFilesJupy/df.csv')
planets
# Out:
#     Planet       Mass  Diameter  DayLength  SunDistance  OrbitPeriod  \
# 0  MERCURY     0.3300      4879     4222.6         57.9         88.0
# 1    VENUS     4.8700     12104     2802.0        108.2        224.7
# 2    EARTH     5.9700     12756       24.0        149.6        365.2
# 3     MOON     0.0730      3475      708.7          NaN         27.3
# 4     MARS     0.6420      6792       24.7        227.9        687.0
# 5  JUPITER  1898.0000    142984        9.9        778.6       4331.0
# 6   SATURN   568.0000    120536       10.7       1433.5      10747.0
# 7   URANUS    86.8000     51118       17.2       2872.5      30589.0
# 8  NEPTUNE   102.0000     49528       16.1       4495.1      59800.0
# 9    PLUTO     0.0146      2370      153.3       5906.4      90560.0
#
#    OrbitVelocity  Temperature  SurfacePressure  Moons Rings MagneticField  \
# 0           47.4          167          0.00000      0    No           Yes
# ...

# %%
planets['Mass']
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
planets.Mass
# Out:
# 0       0.3300
# 1       4.8700
# 2       5.9700
# 3       0.0730
# 4       0.6420
# 5    1898.0000
# 6     568.0000
# 7      86.8000
# 8     102.0000
# 9       0.0146
# Name: Mass, dtype: float64

# %%
planets.loc[0] # looking at properties of planet by index
# Out:
# Planet                MERCURY
# Mass                     0.33
# Diameter                 4879
# DayLength              4222.6
# SunDistance              57.9
# OrbitPeriod                88
# OrbitVelocity            47.4
# Temperature               167
# SurfacePressure             0
# Moons                       0
# Rings                      No
# MagneticField             Yes
# FirstVisited       1974-03-29
# FirstMission       Mariner 10
# Name: 0, dtype: object

# %%
planets.set_index('Planet', inplace=True)

# %%
planets
# Out:
#               Mass  Diameter  DayLength  SunDistance  OrbitPeriod  \
# Planet
# MERCURY     0.3300      4879     4222.6         57.9         88.0
# VENUS       4.8700     12104     2802.0        108.2        224.7
# EARTH       5.9700     12756       24.0        149.6        365.2
# MOON        0.0730      3475      708.7          NaN         27.3
# MARS        0.6420      6792       24.7        227.9        687.0
# JUPITER  1898.0000    142984        9.9        778.6       4331.0
# SATURN    568.0000    120536       10.7       1433.5      10747.0
# URANUS     86.8000     51118       17.2       2872.5      30589.0
# NEPTUNE   102.0000     49528       16.1       4495.1      59800.0
# PLUTO       0.0146      2370      153.3       5906.4      90560.0
#
#          OrbitVelocity  Temperature  SurfacePressure  Moons Rings  \
# Planet
# MERCURY           47.4          167          0.00000      0    No
# VENUS             35.0          464         92.00000      0    No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 14 columns):
# Planet             10 non-null object
# Mass               10 non-null float64
# Diameter           10 non-null int64
# DayLength          10 non-null float64
# SunDistance        10 non-null object
# OrbitPeriod        10 non-null float64
# OrbitVelocity      10 non-null float64
# Temperature        10 non-null int64
# SurfacePressure    10 non-null object
# Moons              10 non-null int64
# Rings              10 non-null object
# MagneticField      10 non-null object
# FirstVisited       10 non-null object
# FirstMission       10 non-null object
# dtypes: float64(4), int64(3), object(7)
# memory usage: 1.2+ KB

# %%
planets.loc['MERCURY':'EARTH']
# Out:
#          Mass  Diameter  DayLength  SunDistance  OrbitPeriod  OrbitVelocity  \
# Planet
# MERCURY  0.33      4879     4222.6         57.9         88.0           47.4
# VENUS    4.87     12104     2802.0        108.2        224.7           35.0
# EARTH    5.97     12756       24.0        149.6        365.2           29.8
#
#          Temperature  SurfacePressure  Moons Rings MagneticField FirstVisited  \
# Planet
# MERCURY          167              0.0      0    No           Yes   1974-03-29
# VENUS            464             92.0      0    No            No   1962-08-27
# EARTH             15              1.0      1    No           Yes          NaN
#
#         FirstMission
# Planet
# MERCURY   Mariner 10
# VENUS      Mariner 2
# EARTH            NaN

# %%
planets.FirstVisited['MERCURY']
# Out:
# '1974-03-29'

# %%
planets.loc['MERCURY'].FirstVisited
# Out:
# '1974-03-29'

# %%
planets.loc['MERCURY','FirstVisited']
# Out:
# '1974-03-29'

# %%
type(planets.FirstVisited['MERCURY'])
# Out:
# str

# %%
pd.to_datetime(planets.FirstVisited) # to convert datatime data from str to datetime using pandas
# Out:
# Planet
# MERCURY   1974-03-29
# VENUS     1962-08-27
# EARTH            NaT
# MOON      1959-09-12
# MARS      1965-07-15
# JUPITER   1973-12-04
# SATURN    1979-09-01
# URANUS    1986-01-24
# NEPTUNE   1989-08-25
# PLUTO     2015-07-14
# Name: FirstVisited, dtype: datetime64[ns]

# %%
planets.FirstVisited = pd.to_datetime(planets.FirstVisited) # assigned to column on dataset

# %%
planets.FirstVisited.dt.year # we can now perform several operations using dt
# Out:
# Planet
# MERCURY    1974.0
# VENUS      1962.0
# EARTH         NaN
# MOON       1959.0
# MARS       1965.0
# JUPITER    1973.0
# SATURN     1979.0
# URANUS     1986.0
# NEPTUNE    1989.0
# PLUTO      2015.0
# Name: FirstVisited, dtype: float64

# %%
2020 - planets.FirstVisited.dt.year # tells us how many years ago these places were visited
# Out:
# Planet
# MERCURY    46.0
# VENUS      58.0
# EARTH       NaN
# MOON       61.0
# MARS       55.0
# JUPITER    47.0
# SATURN     41.0
# URANUS     34.0
# NEPTUNE    31.0
# PLUTO       5.0
# Name: FirstVisited, dtype: float64

# %%
#!file billboard.csv - corrects utfe errors in loading a file
# billboard = pd.read_csv('billboard.csv', encoding='latin-1')
# pp.plot(billboard.loc[0,'column1':'columnx']) plots 
# pp.plot(range(1, 77), billboard.loc[0,'':'']) plots with range specification

# bshort.columns = ['', '', '', ''] - directly updates columns
# bmelt = bshort.melt(['col1','col2'],['wk1', 'wk2'], 'week','rank') - melts wk1, wk2, to week

# bmelt.query['track' == 'Liar'] - selects specific songs

# bmelt['week'] = bmelt['week'].apply(lambda s: int(s[2])) converts 3rd string eg in wk1 to 1

# bmelt['date.entered'] = pd.to_datetime(bmelt[date.entered])

# bmelt['date.entered'][0] + pd.Timedelta('7 days') - performs datetime calculation

# bmelt.drop(['date.entered'], axis=1, inplace=True) - drops date.entered

# tracks = bfinal[['','','']].drop_duplicates()

# pd.merge(tracksid, bfinal, on = ['track', 'artist']).head()

# %%
planets
# Out:
#               Mass  Diameter  DayLength  SunDistance  OrbitPeriod  \
# Planet
# MERCURY     0.3300      4879     4222.6         57.9         88.0
# VENUS       4.8700     12104     2802.0        108.2        224.7
# EARTH       5.9700     12756       24.0        149.6        365.2
# MOON        0.0730      3475      708.7          NaN         27.3
# MARS        0.6420      6792       24.7        227.9        687.0
# JUPITER  1898.0000    142984        9.9        778.6       4331.0
# SATURN    568.0000    120536       10.7       1433.5      10747.0
# URANUS     86.8000     51118       17.2       2872.5      30589.0
# NEPTUNE   102.0000     49528       16.1       4495.1      59800.0
# PLUTO       0.0146      2370      153.3       5906.4      90560.0
#
#          OrbitVelocity  Temperature  SurfacePressure  Moons Rings  \
# Planet
# MERCURY           47.4          167          0.00000      0    No
# VENUS             35.0          464         92.00000      0    No
# ...

# %%
melted = planets.melt(['Mass', 'Diameter', 'SunDistance', 'OrbitPeriod', 'OrbitVelocity', 'Temperature', 'SurfacePressure', 'Moons'], ['Rings', 'MagneticField', 'FirstVisited', 'FirstMission'], 'Remainder', 'Cases')

# %%
melted.head()
# Out:
#     Mass  Diameter  SunDistance  OrbitPeriod  OrbitVelocity  Temperature  \
# 0  0.330      4879         57.9         88.0           47.4          167
# 1  4.870     12104        108.2        224.7           35.0          464
# 2  5.970     12756        149.6        365.2           29.8           15
# 3  0.073      3475          NaN         27.3            1.0          -20
# 4  0.642      6792        227.9        687.0           24.1          -65
#
#    SurfacePressure  Moons Remainder Cases
# 0             0.00      0     Rings    No
# 1            92.00      0     Rings    No
# 2             1.00      1     Rings    No
# 3             0.00      0     Rings    No
# 4             0.01      2     Rings    No

# %%
melted.drop(['Remainder','Cases'], axis=1, inplace=True)

# %%
melted
# Out:
#          Mass  Diameter  SunDistance  OrbitPeriod  OrbitVelocity  Temperature  \
# 0      0.3300      4879         57.9         88.0           47.4          167
# 1      4.8700     12104        108.2        224.7           35.0          464
# 2      5.9700     12756        149.6        365.2           29.8           15
# 3      0.0730      3475          NaN         27.3            1.0          -20
# 4      0.6420      6792        227.9        687.0           24.1          -65
# 5   1898.0000    142984        778.6       4331.0           13.1         -110
# 6    568.0000    120536       1433.5      10747.0            9.7         -140
# 7     86.8000     51118       2872.5      30589.0            6.8         -195
# 8    102.0000     49528       4495.1      59800.0            5.4         -200
# 9      0.0146      2370       5906.4      90560.0            4.7         -225
# 10     0.3300      4879         57.9         88.0           47.4          167
# ...

# %%
tracks = melted[['Mass', 'Diameter', 'SunDistance', 'OrbitPeriod', 'OrbitVelocity', 'Temperature', 'SurfacePressure', 'Moons']].drop_duplicates()

# %%
tracks
# Out:
#         Mass  Diameter  SunDistance  OrbitPeriod  OrbitVelocity  Temperature  \
# 0     0.3300      4879         57.9         88.0           47.4          167
# 1     4.8700     12104        108.2        224.7           35.0          464
# 2     5.9700     12756        149.6        365.2           29.8           15
# 3     0.0730      3475          NaN         27.3            1.0          -20
# 4     0.6420      6792        227.9        687.0           24.1          -65
# 5  1898.0000    142984        778.6       4331.0           13.1         -110
# 6   568.0000    120536       1433.5      10747.0            9.7         -140
# 7    86.8000     51118       2872.5      30589.0            6.8         -195
# 8   102.0000     49528       4495.1      59800.0            5.4         -200
# 9     0.0146      2370       5906.4      90560.0            4.7         -225
#
#    SurfacePressure  Moons
# 0          0.00000      0
# 1         92.00000      0
# 2          1.00000      1
# ...
